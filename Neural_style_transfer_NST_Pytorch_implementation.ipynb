# %% [markdown]
# <a href="https://colab.research.google.com/github/martinpius/Computer-Vission/blob/main/Neural_style_transfer_NST_Pytorch_implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount = True)
try:
  COLAB = True
  import torch
  print(f">>>> You are on CoLaB with torch version {torch.__version__}")
except Exception as e:
  print(f">>>> {type(e)}: {e}\n>>>> please correct {type(e)} and re-load your drive")
def time_fmt(t: float = 132.19)->float:
  h = int(t / (60 * 60))
  m = int(t % (60 * 60) / 60)
  s = int(t % 60)
  return f"hrs: {h} min: {m:>02} sec: {s:>05.2f}"
if torch.cuda.is_available():
  device = torch.device("cuda")
else:
  device = torch.device("cpu")
print(f">>>> testing time formating function....\n>>>> time elapsed\t{time_fmt()}")
# Out:
# Mounted at /content/drive
# >>>> You are on CoLaB with torch version 1.9.0+cu102
# >>>> testing time formating function....
# >>>> time elapsed	hrs: 0 min: 02 sec: 12.00

# %%
# In this notebook we are going to implement a neural style transfer network from scratch in pytorch.
# The general idea behind the neural style transfer technique is to create a new image by combine the
# contents of two separate images. Training is done by minimizing the two types of losses due to the 
# difference between the target/generated image and the original image, the style image and the generated image.
# so basically we will have three images (the original image, the style image and the generated image== noisy at the start)
# this network make the use of ussual computer vision models such as vggnet where specific layers are identified and trained
# key note: the weights of the pre-trained network stays frozen  and in training we only want the noisy-image to resemble the 
# original image with the style of the style-image ie, we are modifying inputs rather than the weights!!!!!!!!
# In this implementantion we consider vgg19 architecture(pre-trained net). We discard the classifier and select every convolutional
# layer which comes after the maxpooling.
# THE LOSS FUNCTION COMBINE TWO COMPONENTS - THE STYLE LOSS AND THE CONTENT LOSS connected by two hyper-parameters
# Loss = J_content[alpha*L(C, G)] + J_style[beta*L(C,S)] where C== loss contribution due to content(original image)
# S and G due to stlye and generated images. The content loss is simply the norm of every layer between the content and generated 
# images. For the style loss we need to compute Grahm matrices for the style and generated images.

# %%
import torch, torchvision, os
import torchvision.transforms as transforms
import random, time, datetime
import numpy as np
import torch.nn as nn
import torch.optim as optim
from tensorflow import summary
from torchvision.utils import save_image
from PIL import Image
# %load_ext tensorboard

# %%
os.chdir("/content/drive/MyDrive/NLT")

# %%
# set the seed values for reproducability:
seed = 1234
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True

# %%
# We start by loading and extracting the layers of vgg19 pretrained network
model = torchvision.models.vgg19(pretrained = True).features
print(model)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# HBox(children=(FloatProgress(value=0.0, max=574673361.0), HTML(value='')))
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU(inplace=True)
#   (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU(inplace=True)
#   (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (6): ReLU(inplace=True)
#   (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (8): ReLU(inplace=True)
#   (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(inplace=True)
#   (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (13): ReLU(inplace=True)
#   (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (15): ReLU(inplace=True)
#   (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (17): ReLU(inplace=True)
#   (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (20): ReLU(inplace=True)
#   (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (22): ReLU(inplace=True)
#   (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (24): ReLU(inplace=True)
#   (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (26): ReLU(inplace=True)
#   (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (29): ReLU(inplace=True)
#   (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (31): ReLU(inplace=True)
#   (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (33): ReLU(inplace=True)
#   (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (35): ReLU(inplace=True)
#   (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )

# %%
# we select layer after every maxpooling start with  layer 0:
class VGG_Edited(nn.Module):
  def __init__(self):
    super(VGG_Edited, self).__init__()
    self.selected_layers = ["0", "5", "10", "19","28"]
    # so basically we need the layers up to 28th as seen from the print above
    self.model = torchvision.models.vgg19(pretrained = True).features[:29]

  def forward(self, input_tensor):
    features = [] # container for features related to the selected layers
    for layer_num, layer in enumerate(self.model):
      # pass the input (image) and place to the container 
      # the features corresponds to the selected layers
      input_tensor = layer(input_tensor) # output after apssing through the selected conv-layer
      if str(layer_num) in self.selected_layers:
        features.append(input_tensor)
    return features

# %%
# We now load an image using the following function:
def load_image(img_name):
  image = Image.open(img_name)
  # transform and add batch dimension
  image = mytransform(image).unsqueeze(0)
  return image.to(device = device)

# %%
mytransform = transforms.Compose([
                                  transforms.Resize((356, 356)),
                                  transforms.ToTensor(),
                                  
])

# %%
# Load in the data (only 3 images)
orig_img = load_image("che.jpeg")
style_img = load_image("orig.jpg")
# we may create a noisy image or copy the original image as generate image to start with
generated = orig_img.clone().requires_grad_(True)
# instantiate the model class
model = VGG_Edited().to(device = device).eval()
print(orig_img.shape)
print(style_img.shape)
print(generated.shape)
# Out:
# torch.Size([1, 3, 356, 356])
# torch.Size([1, 3, 356, 356])
# torch.Size([1, 3, 356, 356])

# %%
# Model's Hyperparameters
alpha = 1 # for the content loss
beta = 0.01 # for the style loss
EPOCHS = 5000
learning_rate = 1e-3
optimizer = optim.Adam(params = [generated], lr = learning_rate)

tic = time.time()
for epoch in range(EPOCHS):
  print(f"\n>>>> train start for epoch {epoch + 1}\n>>>> please wait while the model is training")
  generated_features = model(generated)
  org_features = model(orig_img)
  style_features = model(style_img)
  # computing the loss at every conv-layer (5 of them)
  style_loss = 0
  content_loss = 0
  for g_feature, s_feature, o_feature in zip(generated_features, style_features, org_features):
    batch, c, h, w = g_feature.shape
    content_loss+= torch.mean((g_feature - o_feature)**2)
    # we now compute the Grahm matrices to get style loss
    G = g_feature.view(c, h*w).mm(g_feature.view(c, h*w).t()) # for the generated img
    A = s_feature.view(c, h*w).mm(s_feature.view(c, h*w).t()) # for the style img
    style_loss+= torch.mean((G-A)**2)
  # the total loss will be
  total_loss = alpha * content_loss + beta * style_loss
  optimizer.zero_grad()
  total_loss.backward()
  optimizer.step()

  if epoch % 200 == 0:
    print(f"\n>>>> total loss is {total_loss:.4f}")
    save_image(generated, 'marto_che.png')
toc = time.time()
print(f"\n>>>> total time elapsed: {time_fmt(toc - tic)}")
# Out:
# Streaming output truncated to the last 5000 lines.
# >>>> train start for epoch 3340
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3341
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3342
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3343
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3344
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3345
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3346
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3347
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3348
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3349
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3350
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3351
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3352
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3353
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3354
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3355
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3356
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3357
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3358
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3359
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3360
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3361
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3362
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3363
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3364
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3365
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3366
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3367
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3368
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3369
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3370
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3371
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3372
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3373
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3374
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3375
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3376
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3377
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3378
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3379
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3380
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3381
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3382
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3383
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3384
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3385
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3386
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3387
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3388
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3389
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3390
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3391
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3392
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3393
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3394
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3395
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3396
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3397
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3398
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3399
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3400
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3401
# >>>> please wait while the model is training
#
# >>>> total loss is 293.4866
#
# >>>> train start for epoch 3402
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3403
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3404
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3405
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3406
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3407
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3408
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3409
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3410
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3411
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3412
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3413
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3414
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3415
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3416
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3417
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3418
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3419
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3420
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3421
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3422
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3423
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3424
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3425
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3426
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3427
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3428
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3429
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3430
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3431
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3432
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3433
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3434
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3435
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3436
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3437
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3438
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3439
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3440
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3441
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3442
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3443
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3444
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3445
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3446
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3447
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3448
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3449
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3450
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3451
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3452
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3453
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3454
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3455
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3456
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3457
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3458
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3459
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3460
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3461
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3462
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3463
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3464
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3465
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3466
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3467
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3468
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3469
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3470
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3471
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3472
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3473
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3474
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3475
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3476
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3477
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3478
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3479
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3480
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3481
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3482
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3483
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3484
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3485
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3486
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3487
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3488
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3489
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3490
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3491
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3492
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3493
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3494
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3495
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3496
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3497
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3498
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3499
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3500
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3501
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3502
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3503
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3504
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3505
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3506
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3507
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3508
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3509
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3510
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3511
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3512
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3513
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3514
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3515
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3516
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3517
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3518
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3519
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3520
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3521
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3522
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3523
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3524
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3525
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3526
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3527
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3528
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3529
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3530
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3531
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3532
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3533
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3534
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3535
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3536
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3537
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3538
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3539
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3540
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3541
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3542
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3543
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3544
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3545
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3546
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3547
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3548
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3549
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3550
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3551
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3552
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3553
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3554
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3555
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3556
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3557
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3558
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3559
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3560
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3561
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3562
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3563
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3564
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3565
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3566
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3567
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3568
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3569
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3570
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3571
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3572
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3573
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3574
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3575
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3576
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3577
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3578
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3579
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3580
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3581
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3582
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3583
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3584
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3585
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3586
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3587
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3588
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3589
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3590
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3591
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3592
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3593
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3594
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3595
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3596
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3597
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3598
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3599
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3600
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3601
# >>>> please wait while the model is training
#
# >>>> total loss is 270.6534
#
# >>>> train start for epoch 3602
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3603
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3604
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3605
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3606
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3607
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3608
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3609
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3610
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3611
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3612
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3613
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3614
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3615
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3616
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3617
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3618
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3619
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3620
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3621
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3622
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3623
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3624
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3625
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3626
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3627
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3628
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3629
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3630
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3631
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3632
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3633
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3634
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3635
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3636
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3637
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3638
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3639
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3640
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3641
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3642
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3643
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3644
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3645
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3646
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3647
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3648
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3649
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3650
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3651
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3652
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3653
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3654
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3655
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3656
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3657
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3658
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3659
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3660
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3661
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3662
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3663
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3664
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3665
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3666
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3667
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3668
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3669
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3670
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3671
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3672
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3673
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3674
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3675
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3676
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3677
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3678
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3679
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3680
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3681
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3682
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3683
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3684
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3685
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3686
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3687
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3688
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3689
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3690
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3691
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3692
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3693
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3694
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3695
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3696
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3697
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3698
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3699
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3700
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3701
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3702
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3703
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3704
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3705
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3706
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3707
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3708
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3709
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3710
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3711
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3712
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3713
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3714
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3715
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3716
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3717
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3718
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3719
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3720
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3721
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3722
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3723
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3724
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3725
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3726
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3727
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3728
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3729
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3730
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3731
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3732
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3733
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3734
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3735
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3736
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3737
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3738
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3739
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3740
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3741
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3742
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3743
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3744
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3745
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3746
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3747
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3748
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3749
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3750
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3751
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3752
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3753
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3754
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3755
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3756
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3757
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3758
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3759
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3760
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3761
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3762
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3763
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3764
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3765
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3766
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3767
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3768
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3769
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3770
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3771
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3772
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3773
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3774
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3775
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3776
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3777
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3778
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3779
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3780
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3781
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3782
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3783
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3784
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3785
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3786
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3787
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3788
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3789
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3790
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3791
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3792
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3793
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3794
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3795
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3796
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3797
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3798
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3799
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3800
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3801
# >>>> please wait while the model is training
#
# >>>> total loss is 250.9937
#
# >>>> train start for epoch 3802
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3803
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3804
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3805
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3806
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3807
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3808
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3809
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3810
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3811
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3812
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3813
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3814
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3815
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3816
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3817
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3818
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3819
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3820
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3821
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3822
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3823
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3824
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3825
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3826
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3827
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3828
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3829
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3830
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3831
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3832
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3833
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3834
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3835
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3836
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3837
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3838
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3839
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3840
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3841
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3842
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3843
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3844
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3845
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3846
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3847
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3848
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3849
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3850
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3851
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3852
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3853
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3854
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3855
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3856
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3857
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3858
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3859
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3860
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3861
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3862
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3863
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3864
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3865
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3866
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3867
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3868
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3869
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3870
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3871
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3872
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3873
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3874
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3875
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3876
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3877
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3878
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3879
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3880
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3881
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3882
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3883
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3884
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3885
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3886
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3887
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3888
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3889
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3890
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3891
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3892
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3893
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3894
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3895
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3896
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3897
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3898
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3899
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3900
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3901
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3902
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3903
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3904
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3905
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3906
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3907
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3908
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3909
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3910
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3911
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3912
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3913
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3914
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3915
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3916
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3917
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3918
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3919
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3920
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3921
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3922
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3923
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3924
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3925
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3926
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3927
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3928
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3929
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3930
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3931
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3932
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3933
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3934
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3935
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3936
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3937
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3938
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3939
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3940
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3941
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3942
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3943
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3944
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3945
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3946
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3947
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3948
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3949
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3950
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3951
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3952
# >>>> please wait while the model is training
#
# >>>> train start for epoch 3953
# ...
#
# >>>> train start for epoch 4797
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4798
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4799
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4800
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4801
# >>>> please wait while the model is training
#
# >>>> total loss is 185.0406
#
# >>>> train start for epoch 4802
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4803
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4804
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4805
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4806
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4807
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4808
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4809
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4810
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4811
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4812
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4813
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4814
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4815
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4816
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4817
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4818
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4819
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4820
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4821
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4822
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4823
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4824
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4825
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4826
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4827
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4828
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4829
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4830
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4831
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4832
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4833
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4834
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4835
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4836
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4837
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4838
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4839
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4840
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4841
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4842
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4843
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4844
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4845
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4846
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4847
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4848
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4849
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4850
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4851
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4852
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4853
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4854
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4855
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4856
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4857
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4858
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4859
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4860
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4861
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4862
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4863
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4864
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4865
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4866
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4867
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4868
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4869
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4870
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4871
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4872
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4873
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4874
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4875
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4876
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4877
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4878
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4879
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4880
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4881
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4882
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4883
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4884
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4885
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4886
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4887
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4888
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4889
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4890
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4891
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4892
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4893
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4894
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4895
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4896
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4897
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4898
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4899
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4900
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4901
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4902
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4903
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4904
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4905
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4906
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4907
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4908
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4909
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4910
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4911
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4912
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4913
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4914
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4915
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4916
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4917
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4918
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4919
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4920
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4921
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4922
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4923
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4924
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4925
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4926
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4927
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4928
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4929
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4930
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4931
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4932
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4933
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4934
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4935
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4936
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4937
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4938
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4939
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4940
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4941
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4942
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4943
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4944
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4945
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4946
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4947
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4948
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4949
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4950
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4951
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4952
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4953
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4954
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4955
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4956
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4957
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4958
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4959
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4960
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4961
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4962
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4963
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4964
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4965
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4966
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4967
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4968
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4969
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4970
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4971
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4972
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4973
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4974
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4975
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4976
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4977
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4978
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4979
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4980
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4981
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4982
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4983
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4984
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4985
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4986
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4987
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4988
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4989
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4990
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4991
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4992
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4993
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4994
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4995
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4996
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4997
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4998
# >>>> please wait while the model is training
#
# >>>> train start for epoch 4999
# >>>> please wait while the model is training
#
# >>>> train start for epoch 5000
# >>>> please wait while the model is training
#
# >>>> total time elapsed: hrs: 0 min: 23 sec: 53.00
